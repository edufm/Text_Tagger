# %%
import pandas as pd
import numpy as np

# %%
name = "Tweets_USA.csv"
dataset = pd.read_csv(f"./datasets/{name}")

# %%
dataset.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            Tweet Id        Date   Hour  \
# 0           0             0  721318437075685382  2016-04-16  12:44
# 1           1             1  721318436173979648  2016-04-16  12:44
# 2           2             2  721318434169102336  2016-04-16  12:44
# 3           3             3  721318429844582400  2016-04-16  12:44
# 4           4             4  721318429081407488  2016-04-16  12:44
#
#           User Name       Nickname  \
# 0    Bill Schulhoff  BillSchulhoff
# 1     Daniele Polis      danipolis
# 2      Kasey Jacobs      KJacobs27
# 3       Stan Curtis      stncurtis
# 4  Dave Borzymowski       wi_borzo
#
#                                                  Bio  \
# 0  Husband,Dad,GrandDad,Ordained Minister, Umpire...
# 1  Viagens, geek, moda, batons laranja, cabelos c...
# 2                   Norwich University Class of 2017
# 3  transcendental music, art for art's sake, craf...
# 4                            When in doubt....Panic.
#
# ...

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Tweet Id', 'Date', 'Hour', 'User Name',
#        'Nickname', 'Bio', 'Tweet content', 'Favs', 'RTs', 'Latitude',
#        'Longitude', 'Country', 'Place (as appears on Bio)', 'Profile picture',
#        'Followers', 'Following', 'Listed', 'Tweet language (ISO 639-1)',
#        'Tweet Url'],
#       dtype='object')

# %%
to_drop = ['Tweet Id', 'Date', 'Hour', 'User Name', 'Nickname', 'Bio', 'Favs', 'RTs', 'Country',
           'Place (as appears on Bio)', 'Profile picture', 'Followers',
           'Following', 'Listed', 'Tweet language (ISO 639-1)', 'Tweet Url']
dataset = dataset.drop(to_drop, axis=1)
dataset.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                        Tweet content   Latitude  Longitude
# 0  Wind 3.2 mph NNE. Barometer 30.20 in, Rising s...  40.760278 -72.954722
# 1  Pausa pro café antes de embarcar no próximo vô...  32.898349 -97.039196
# 2  Good. Morning. #morning #Saturday #diner #VT #...  44.199476 -72.504173
# 3  @gratefuldead recordstoredayus 🌹🌹🌹 @ TOMS MUSI...  39.901474 -76.606817
# 4  Egg in a muffin!!! (@ Rocket Baby Bakery - @ro...  43.060849 -87.998309

# %%
dataset.to_csv(f"./datasets/{name}")
dataset.loc[np.random.permutation(np.array(dataset.index))[:1000]].to_csv(f"./datasets_samples/{name}")
